# %% [markdown]
# Author: Mario Roca

# %%
import numpy as np

# %% [markdown]
# ## Explore npy structures (recursive)

# %%
def explore_structure(data, level=0):
    indent = "  " * level
    if isinstance(data, dict):
        print(f"{indent}Dict with keys: {list(data.keys())}")
        for key, value in data.items():
            print(f"{indent}Exploring key '{key}':")
            explore_structure(value, level + 1)
    elif isinstance(data, list):
        print(f"{indent}List of {len(data)} items")
        for i, item in enumerate(data[:3]):  # Limit to first 3 items for brevity
            print(f"{indent}Exploring list item {i}:")
            explore_structure(item, level + 1)
    elif isinstance(data, np.ndarray):
        print(f"{indent}Array with shape {data.shape} and dtype {data.dtype}")
        print(f"{indent}Content (first element): {data.ravel()[:4]}")  # Display first few elements
    else:
        print(f"{indent}{type(data)}: {data}")

# %%
# The data structure is a nested dictionary with the following hierarchy:
# 
# 1. The outermost dictionary has keys representing patient IDs or identifiers (e.g., '2107_1', '2126_1').
# 2. Each patient ID maps to a list containing a single dictionary.
# 3. This inner dictionary has keys representing different statuses or conditions (e.g., '10', '20', '16').
# 4. Each status key maps to a list containing a single NumPy array.
# 5. These NumPy arrays have shapes indicating the number of samples and channels (e.g., (1249, 4) means 1249 samples and 4 channels).
# 6. The arrays contain EEG signal data with dtype float64.
# 
# Example structure:
# {
#     '2107_1': [
#         {
#             '10': [array with shape (1249, 4)],
#             '20': [array with shape (389, 4)],
#             '16': [array with shape (6366, 4)],
#             ...
#         }
#     ],
#     '2126_1': [
#         {
#             '10': [array with shape (1260, 4)],
#             '20': [array with shape (559, 4)],
#             '15': [array with shape (6161, 4)],
#             ...
#         }
#     ],
#     ...
# }
# 
# Usage:
# - The outermost dictionary allows access to data for each patient.
# - For each patient, the list contains a dictionary with different statuses.
# - Each status key maps to a list containing a NumPy array of EEG signal data.
# - The arrays can be accessed and processed for feature extraction, analysis, or modeling.

# %%
# Load the EEG signals file
eeg_signals = np.load("Data/eeg_signals.npy", allow_pickle=True).item()
# Usage
explore_structure(eeg_signals)
# Out:
# Dict with keys: ['2107_1', '2126_1', '2104_2', '2123_1', '2124_2', '2113_1', '2122_1', '2110_1', '2121_1', '2104_1', '2114_1', '2131_2', '2120_1', '2112_1', '2115_1', '2117_1', '2119_1', '2130_1', '2131_1', '2109_1', '2129_1', '2116_1', '2134_1', '2133_1', '2111_1', '2108_1', '2132_1', '2127_1', '2106_1', '2124_1', '2125_1', '2136_1']
# Exploring key '2107_1':
#   List of 1 items
#   Exploring list item 0:
#     Dict with keys: ['10', '20', '16', '26', '10_1', '20_2', '15', '25', '10_3', '20_4', '14', '24', '10_5', '20_6', '13', '23', '10_7', '20_8', '12', '22', '10_9', '20_10', '11']
#     Exploring key '10':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (1249, 4) and dtype float64
#         Content (first element): [862.96583166 832.80086522 901.64134202 853.19858563]
#     Exploring key '20':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (389, 4) and dtype float64
#         Content (first element): [835.43051946 825.63288986 860.68306938 835.38339463]
#     Exploring key '16':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (6366, 4) and dtype float64
#         Content (first element): [899.34369404 765.0448014  819.17135991 892.87205558]
#     Exploring key '26':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (3608, 4) and dtype float64
#         Content (first element): [848.94831004 726.73420378 879.52724466 861.92339642]
#     Exploring key '10_1':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (1239, 4) and dtype float64
#         Content (first element): [890.19323553 805.27861427 691.79977261 908.68474009]
#     Exploring key '20_2':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape

#     Exploring key '13':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (5838, 4) and dtype float64
#         Content (first element): [855.06552759 806.72612661 702.46475804 845.09779876]
#     Exploring key '23':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (3888, 4) and dtype float64
#         Content (first element): [886.22209702 795.62950336 729.67186265 857.50299444]
#     Exploring key '10_9':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (1279, 4) and dtype float64
#         Content (first element): [877.11783593 869.44771424 949.41411707 855.18159729]
#     Exploring key '20_10':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (309, 4) and dtype float64
#         Content (first element): [867.67238313 890.53254762 976.24500132 859.16747292]
#     Exploring key '11':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (5818, 4) and dtype float64
#         Content (first element): [832.53267792 869.9268845  879.53344447 833.21003766]
# Exploring key '2110_1':
#   List of 1 items
#   Exploring list item 0:
#     Dict with keys: ['10', '20', '16', '26', '10_1', '20_2', '15', '25', '10_3', '20_4', '14', '24', '10_5', '20_6', '13', '23', '10_7', '20_8', '12', '22', '10_9', '20_10', '11']
#     Exploring key '10':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (1229, 4) and dtype float64
#         Content (first element): [843.34346995 841.87936865 811.97054703 905.06215476]
#     Exploring key '20':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (460, 4) and dtype float64
#         Content (first element): [854.12437054 842.71452507 883.40159936 898.82292767]
#     Exploring key '16':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (6400, 4) and dtype float64
#         Content (first element): [804.02861697 829.48472956 833.56791192 769.56930519]
#     Exploring key '26':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (3180, 4) and dtype float64
#         Content (first element): [826.98546992 832.40565013 823.70641664 873.51750981]
#     Exploring key '10_1':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (1219, 4) and dtype float64
#         Content (first element): [872.58770469 832.29731376 968.52811765 848.89710062]
#     Exploring key '20_2':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (630, 4) and dtype float64
#         Content (first element): [891.67170379 831.53148463 685.07487643 860.6313153 ]
#     Exploring key '15':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (6139, 4) and dtype float64
#         Content (first element): [868.41210397 833.7433226  862.97174769 829.60688471]
#     Exploring key '25':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (3720, 4) and dtype float64
#         Content (first element): [855.71790862 831.00505504 816.5017333  838.90214294]
#     Exploring key '10_3':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (1210, 4) and dtype float64
#         Content (first element): [852.23988811 833.11883202 695.19926044 836.60859312]
#     Exploring key '20_4':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (400, 4) and dtype float64
#         Content (first element): [873.93347682 832.2583744  774.05772171 817.38381906]
#     Exploring key '14':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (6240, 4) and dtype float64
#         Content (first element): [860.78719184 832.43583279 820.8562658  803.68247536]
#     Exploring key '24':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (5940, 4) and dtype float64
#         Content (first element): [847.23887234 836.737165   842.14055047 818.73397175]
#     Exploring key '10_5':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (1219, 4) and dtype float64
#         Content (first element): [854.5048855  828.17113643 690.98863425 834.41011516]
#     Exploring key '20_6':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (340, 4) and dtype float64
#         Content (first element): [781.81684747 827.28449936 677.9780543  721.09244861]
#     Exploring key '13':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (5850, 4) and dtype float64
#         Content (first element): [849.3557195  823.72479378 794.73933613 908.80688029]
#     Exploring key '23':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (3040, 4) and dtype float64
#         Content (first element): [870.489967   826.28397793 814.85003241 876.93040646]
#     Exploring key '10_7':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (1230, 4) and dtype float64
#         Content (first element): [865.54096345 836.48419479 700.24681892 846.0926427 ]
#     Exploring key '20_8':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (259, 4) and dtype float64
#         Content (first element): [858.18931611 844.74659331 742.68930579 838.08696128]
#     Exploring key '12':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (5860, 4) and dtype float64
#         Content (first element): [823.07499268 851.18965846 763.09562201 819.02687556]
#     Exploring key '22':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (3249, 4) and dtype float64
#         Content (first element): [857.80101078 838.96754318 847.71696514 849.97683436]
#     Exploring key '10_9':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (1230, 4) and dtype float64
#         Content (first element): [889.78865631 836.11574581 853.39131378 903.5613589 ]
#     Exploring key '20_10':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (289, 4) and dtype float64
#         Content (first element): [885.78480384 842.15259151 744.7048266  913.81548907]
#     Exploring key '11':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (5851, 4) and dtype float64
#         Content (first element): [852.9660297  831.25209529 881.95250653 851.45710523]
# Exploring key '2121_1':
#   List of 1 items
#   Exploring list item 0:
#     Dict with keys: ['10', '20', '12', '22', '10_1', '20_2', '11', '21', '10_3', '20_4', '13', '23', '10_5', '20_6', '15', '25', '10_7', '20_8', '14', '24', '10_9', '20_10', '16']
#     Exploring key '10':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (1279, 4) and dtype float64
#         Content (first element): [882.56989257 821.18858381 780.92928729 883.07052906]
#     Exploring key '20':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (240, 4) and dtype float64
#         Content (first element): [856.56173614 827.37025074 778.12223536 855.16678978]
#     Exploring key '12':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (5840, 4) and dtype float64
#         Content (first element): [848.40167893 845.04008313 749.3590216  845.88261257]
#     Exploring key '22':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (6640, 4) and dtype float64
#         Content (first element): [832.82147878 854.18868782 840.98446057 905.83107482]
#     Exploring key '10_1':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (1309, 4) and dtype float64
#         Content (first element): [826.7399181  834.13777893 850.67766127 911.90814921]
#     Exploring key '20_2':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (230, 4) and dtype float64
#         Content (first element): [899.30341832 831.6338833  889.292141   825.34099156]
#     Exploring key '11':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (5830, 4) and dtype float64
#         Content (first element): [783.01489025 829.47101145 806.49768905 769.97181092]
#     Exploring key '21':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (4171, 4) and dtype float64
#         Content (first element): [776.95664569 837.0251197  817.08516436 779.35466893]
#     Exploring key '10_3':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (1249, 4) and dtype float64
#         Content (first element): [852.92033279 831.34401771 793.39147322 855.29600838]
#     Exploring key '20_4':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (329, 4) and dtype float64
#         Content (first element): [860.22313928 830.84858963 754.56440545 855.75168495]
#     Exploring key '13':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (5840, 4) and dtype float64
#         Content (first element): [836.46618136 827.44547108 775.55029358 846.95302669]
#     Exploring key '23':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (15540, 4) and dtype float64
#         Content (first element): [846.05481229 823.57657426 817.92476451 869.29857236]
#     Exploring key '10_5':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (1260, 4) and dtype float64
#         Content (first element): [892.66473575 825.12037299 763.83343879 908.12088021]
#     Exploring key '20_6':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (579, 4) and dtype float64
#         Content (first element): [766.19737192 835.04456592 754.99087491 762.37577931]
#     Exploring key '15':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (6370, 4) and dtype float64
#         Content (first element): [745.16805255 814.42159636 783.60181616 744.40771606]
#     Exploring key '25':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (3479, 4) and dtype float64
#         Content (first element): [862.88379231 820.93861883 705.82964507 836.10349365]
#     Exploring key '10_7':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (1251, 4) and dtype float64
#         Content (first element): [851.23560511 835.01933542 723.49077344 855.79184904]
#     Exploring key '20_8':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (349, 4) and dtype float64
#         Content (first element): [832.52318034 833.90769023 764.96274357 846.97142528]
#     Exploring key '14':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (6280, 4) and dtype float64
#         Content (first element): [802.93412517 828.10268285 816.28884149 839.87954426]
#     Exploring key '24':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (3610, 4) and dtype float64
#         Content (first element): [786.58520529 829.05200807 820.19871235 868.11154098]
#     Exploring key '10_9':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (1259, 4) and dtype float64
#         Content (first element): [1167.63475212  821.39103549  760.97070943  922.17438787]
#     Exploring key '20_10':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (469, 4) and dtype float64
#         Content (first element): [943.92339326 825.00473495 861.45187889 737.84599402]
#     Exploring key '16':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (6271, 4) and dtype float64
#         Content (first element): [831.21039555 834.823926   866.3243553  849.82796857]
# Exploring key '2104_1':
#   List of 1 items
#   Exploring list item 0:
#     Dict with keys: []
# Exploring key '2114_1':
#   List of 1 items
#   Exploring list item 0:
#     Dict with keys: ['10', '20', '13', '23', '10_1', '20_2', '11', '21', '10_3', '20_4', '12', '22', '10_5', '20_6', '16', '26', '10_7', '20_8', '14', '24', '10_9', '20_10', '15']
#     Exploring key '10':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (1240, 4) and dtype float64
#         Content (first element): [861.73229606 838.16452203 848.11247541 849.40212276]
#     Exploring key '20':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (370, 4) and dtype float64
#         Content (first element): [867.48441021 828.89743029 849.23998618 864.45834974]
#     Exploring key '13':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (5810, 4) and dtype float64
#         Content (first element): [862.7254325  824.08007279 857.87216646 844.30844113]
#     Exploring key '23':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (3379, 4) and dtype float64
#         Content (first element): [838.44547443 830.68439981 842.04131106 821.92389533]
#     Exploring key '10_1':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (1289, 4) and dtype float64
#         Content (first element): [845.21226058 810.33178667 878.47401519 869.81018698]
#     Exploring key '20_2':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (299, 4) and dtype float64
# ...
#     Exploring key '20':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (420, 4) and dtype float64
#         Content (first element): [856.88245128 834.33826544 852.90562938 844.87593027]
#     Exploring key '13':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (5827, 4) and dtype float64
#         Content (first element): [845.70195614 830.13783911 678.01236596 836.26283813]
#     Exploring key '23':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (

#     Exploring key '20_6':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (49, 4) and dtype float64
#         Content (first element): [842.19891098 835.00491282 846.00884905 841.7112543 ]
#     Exploring key '14':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (6557, 4) and dtype float64
#         Content (first element): [837.18764173 809.66789776 849.1037893  823.18007898]
#     Exploring key '24':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (3834, 4) and dtype float64
#         Content (first element): [826.73063    815.84799736 854.98564737 804.81551852]
#     Exploring key '10_7':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (1202, 4) and dtype float64
#         Content (first element): [840.29432007 834.63405112 851.70276993 831.31404218]
#     Exploring key '20_8':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (350, 4) and dtype float64
#         Content (first element): [845.15081654 833.45801001 846.35185436 835.40225059]
#     Exploring key '15':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (6218, 4) and dtype float64
#         Content (first element): [833.48218831 829.09226713 852.39914354 826.09072585]
#     Exploring key '25':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (3323, 4) and dtype float64
#         Content (first element): [854.47798161 844.45930083 851.9175875  838.95456067]
#     Exploring key '10_9':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (1202, 4) and dtype float64
#         Content (first element): [849.92332494 835.50431275 855.41877918 840.05246331]
#     Exploring key '20_10':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (90, 4) and dtype float64
#         Content (first element): [839.60120104 845.68794263 842.17933287 822.94011185]
#     Exploring key '16':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (6107, 4) and dtype float64
#         Content (first element): [849.75880391 838.74362111 840.60208845 842.21886372]

# %%
# The data structure is a nested dictionary with the following hierarchy:
# 
# 1. The outermost dictionary has keys representing patient IDs or identifiers (e.g., '2107_1', '2126_1').
# 2. Each patient ID maps to a list containing a single dictionary.
# 3. This inner dictionary has keys representing different statuses or conditions (e.g., '10', '20', '16').
# 4. Each status key maps to a list containing a single NumPy array.
# 5. These NumPy arrays have shapes indicating the number of samples and channels (e.g., (31311, 1) means 31311 samples and 1 channel).
# 6. The arrays contain ECG signal data with dtype uint16.
# 
# Example structure:
# {
#     '2107_1': [
#         {
#             '10': [array with shape (31311, 1)],
#             '20': [array with shape (9702, 1)],
#             '16': [array with shape (159264, 1)],
#             ...
#         }
#     ],
#     '2126_1': [
#         {
#             '10': [array with shape (31500, 1)],
#             '20': [array with shape (13986, 1)],
#             '15': [array with shape (153972, 1)],
#             ...
#         }
#     ],
#     ...
# }
# 
# Usage:
# - The outermost dictionary allows access to data for each patient.
# - For each patient, the list contains a dictionary with different statuses.
# - Each status key maps to a list containing a NumPy array of ECG signal data.
# - The arrays can be accessed and processed for feature extraction, analysis, or modeling.

# %%
# Load the ECG signals file
ecg_signals = np.load("Data/ecg_signals.npy", allow_pickle=True).item()
# Usage
explore_structure(ecg_signals)
# Out:
# Dict with keys: ['2107_1', '2126_1', '2123_1', '2124_2', '2113_1', '2122_1', '2110_1', '2121_1', '2104_1', '2114_1', '2131_2', '2120_1', '2112_1', '2115_1', '2117_1', '2119_1', '2130_1', '2131_1', '2109_1', '2129_1', '2116_1', '2134_1', '2133_1', '2105_1', '2111_1', '2108_1', '2132_1', '2127_1', '2106_1', '2124_1', '2125_1', '2136_1']
# Exploring key '2107_1':
#   List of 1 items
#   Exploring list item 0:
#     Dict with keys: ['10', '20', '16', '26', '10_1', '20_2', '15', '25', '10_3', '20_4', '14', '24', '10_5', '20_6', '13', '23', '10_7', '20_8', '12', '22', '10_9', '20_10', '11']
#     Exploring key '10':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (31311, 1) and dtype uint16
#         Content (first element): [492 492 492 492]
#     Exploring key '20':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (9702, 1) and dtype uint16
#         Content (first element): [493 492 492 493]
#     Exploring key '16':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (159264, 1) and dtype uint16
#         Content (first element): [504 502 497 491]
#     Exploring key '26':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (90279, 1) and dtype uint16
#         Content (first element): [497 498 498 497]
#     Exploring key '10_1':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (30996, 1) and dtype uint16
#         Content (first element): [491 490 489 489]
#     Exploring key '20_2':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (17703, 1) and dtype uint16
#         Content (first element): [499 500 500 500]
#     Exploring key '15':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (165249, 1) and dtype uint16
#         Content (first element): [499 499 498 497]
#     Exploring key '25':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (119511, 1) and dtype uint16
#         Content (first element): [496 496 496 496]
#     Exploring key '10_3':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (30996, 1) and dtype uint16
#         Content (first element): [498 494 492 491]
#     Exploring key '20_4':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (12789, 1) and dtype uint16
#         Content (first element): [492 492 491 491]
#     Exploring key '14':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (158256, 1) and dtype uint16
#         Content (first element): [497 497 496 496]
#     Exploring key '24':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (146979, 1) and dtype uint16
#         Content (first element): [510 509 509 509]
#     Exploring key '10_5':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (31248, 1) and dtype uint16
#         Content (first element): [501 502 502 502]
#     Exploring key '20_6':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (4725, 1) and dtype uint16
#         Content (first element): [495 495 496 496]
#     Exploring key '13':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (145782, 1) and dtype uint16
#         Content (first element): [495 495 494 494]
#     Exploring key '23':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (82971, 1) and dtype uint16
#         Content (first element): [495 495 495 495]
#     Exploring key '10_7':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (31752, 1) and dtype uint16
#         Content (first element): [508 512 515 514]
#     Exploring key '20_8':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (5481, 1) and dtype uint16
#         Content (first element): [506 507 507 508]
#     Exploring key '12':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (145782, 1) and dtype uint16
#         Content (first element): [504 504 504 503]
#     Exploring key '22':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (86499, 1) and dtype uint16
#         Content (first element): [497 497 497 497]
#     Exploring key '10_9':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (32004, 1) and dtype uint16
#         Content (first element): [503 503 503 503]
#     Exploring key '20_10':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (3717, 1) and dtype uint16
#         Content (first element): [497 497 497 497]
#     Exploring key '11':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (146538, 1) and dtype uint16
#         Content (first element): [505 500 496 494]
# Exploring key '2126_1':
#   List of 1 items
#   Exploring list item 0:
#     Dict with keys: ['10', '20', '15', '25', '10_1', '20_2', '16', '26', '10_3', '20_4', '14', '24', '10_5', '20_6', '12', '22', '10_7', '20_8', '13', '23', '10_9', '20_10', '11']
#     Exploring key '10':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (31500, 1) and dtype uint16
#         Content (first element): [497 496 496 495]
#     Exploring key '20':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (13986, 1) and dtype uint16
#         Content (first element): [493 492 492 492]
#     Exploring key '15':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (153972, 1) and dtype uint16
#         Content (first element): [516 506 493 481]
#     Exploring key '25':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (79758, 1) and dtype uint16
#         Content (first element): [491 491 490 490]
#     Exploring key '10_1':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (32508, 1) and dtype uint16
#         Content (first element): [491 492 492 492]
#     Exploring key '20_2':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (8757, 1) and dtype uint16
#         Content (first element): [495 494 494 494]
#     Exploring key '16':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (154476, 1) and dtype uint16
#         Content (first element): [505 505 504 504]
#     Exploring key '26':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (82278, 1) and dtype uint16
#         Content (first element): [490 490 490 490]
#     Exploring key '10_3':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (32256, 1) and dtype uint16
#         Content (first element): [506 508 509 510]
#     Exploring key '20_4':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (8253, 1) and dtype uint16
#         Content (first element): [491 491 491 492]
#     Exploring key '14':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (162729, 1) and dtype uint16
#         Content (first element): [477 483 487 490]
#     Exploring key '24':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (118251, 1) and dtype uint16
#         Content (first element): [495 494 494 494]
#     Exploring key '10_5':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (31248, 1) and dtype uint16
#         Content (first element): [503 503 503 503]
#     Exploring key '20_6':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (5229, 1) and dtype uint16
#         Content (first element): [494 493 493 493]
#     Exploring key '12':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (145278, 1) and dtype uint16
#         Content (first element): [495 496 497 497]
#     Exploring key '22':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (104013, 1) and dtype uint16
#         Content (first element): [484 484 484 484]
#     Exploring key '10_7':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (31248, 1) and dtype uint16
#         Content (first element): [501 501 500 500]
#     Exploring key '20_8':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (6237, 1) and dtype uint16
#         Content (first element): [491 490 490 490]
#     Exploring key '13':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (145971, 1) and dtype uint16
#         Content (first element): [490 490 490 490]
#     Exploring key '23':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (83286, 1) and dtype uint16
#         Content (first element): [491 491 491 492]
#     Exploring key '10_9':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (32004, 1) and dtype uint16
#         Content (first element): [477 481 486 489]
#     Exploring key '20_10':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (5733, 1) and dtype uint16
#         Content (first element): [493 493 493 493]
#     Exploring key '11':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (146727, 1) and dtype uint16
#         Content (first element): [479 484 488 490]
# Exploring key '2123_1':
#   List of 1 items
#   Exploring list item 0:
#     Dict with keys: ['10', '20', '12', '22', '10_1', '20_2', '11', '21', '10_3', '20_4', '13', '23', '10_5', '20_6', '15', '25', '10_7', '20_8', '14', '24', '10_9', '20_10', '16']
#     Exploring key '10':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (31500, 1) and dtype uint16
#         Content (first element): [480 490 510 538]
#     Exploring key '20':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (6993, 1) and dtype uint16
#         Content (first element): [493 493 493 493]
#     Exploring key '12':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (144711, 1) and dtype uint16
#         Content (first element): [505 504 502 501]
#     Exploring key '22':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (127260, 1) and dtype uint16
#         Content (first element): [495 495 495 496]
#     Exploring key '10_1':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (30492, 1) and dtype uint16
#         Content (first element): [489 489 489 490]
#     Exploring key '20_2':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (6048, 1) and dtype uint16
#         Content (first element): [486 486 487 487]
#     Exploring key '11':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (145971, 1) and dtype uint16
#         Content (first element): [584 577 556 528]
#     Exploring key '21':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (91476, 1) and dtype uint16
#         Content (first element): [489 489 489 489]
#     Exploring key '10_3':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (32256, 1) and dtype uint16
#         Content (first element): [489 489 488 488]
#     Exploring key '20_4':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (5796, 1) and dtype uint16
#         Content (first element): [493 492 491 490]
#     Exploring key '13':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (145971, 1) and dtype uint16
#         Content (first element): [491 491 491 491]
#     Exploring key '23':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (227241, 1) and dtype uint16
#         Content (first element): [491 492 492 492]
#     Exploring key '10_5':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (32004, 1) and dtype uint16
#         Content (first element): [492 492 493 493]
#     Exploring key '20_6':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (13230, 1) and dtype uint16
#         Content (first element): [495 493 491 490]
#     Exploring key '15':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (163296, 1) and dtype uint16
#         Content (first element): [488 488 488 488]
#     Exploring key '25':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (99729, 1) and dtype uint16
#         Content (first element): [483 487 492 495]
#     Exploring key '10_7':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (31500, 1) and dtype uint16
#         Content (first element): [486 487 488 488]
#     Exploring key '20_8':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (7245, 1) and dtype uint16
#         Content (first element): [483 476 479 486]
#     Exploring key '14':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (154980, 1) and dtype uint16
#         Content (first element): [493 493 492 492]
#     Exploring key '24':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (77301, 1) and dtype uint16
#         Content (first element): [492 492 492 492]
#     Exploring key '10_9':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (30996, 1) and dtype uint16
#         Content (first element): [587 586 566 535]
#     Exploring key '20_10':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (94500, 1) and dtype uint16
#         Content (first element): [501 502 503 504]
#     Exploring key '16':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (155484, 1) and dtype uint16
#         Content (first element): [492 492 492 492]
# Exploring key '2124_2':
#   List of 1 items
#   Exploring list item 0:
#     Dict with keys: ['10', '20', '16', '26', '10_1', '20_2', '15', '25', '10_3', '20_4', '14', '24', '10_5', '20_6', '13', '23', '10_7', '20_8', '12']
#     Exploring key '10':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (33768, 1) and dtype uint16
#         Content (first element): [490 490 491 491]
#     Exploring key '20':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (12222, 1) and dtype uint16
#         Content (first element): [489 489 489 489]
#     Exploring key '16':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (155484, 1) and dtype uint16
#         Content (first element): [496 496 496 497]
#     Exploring key '26':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (89523, 1) and dtype uint16
#         Content (first element): [487 487 488 488]
#     Exploring key '10_1':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (32004, 1) and dtype uint16
#         Content (first element): [505 506 507 507]
#     Exploring key '20_2':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (6741, 1) and dtype uint16
#         Content (first element): [483 478 480 484]
#     Exploring key '15':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (156240, 1) and dtype uint16
#         Content (first element): [490 491 491 491]
#     Exploring key '25':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (132489, 1) and dtype uint16
#         Content (first element): [490 490 490 489]
#     Exploring key '10_3':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (32004, 1) and dtype uint16
#         Content (first element): [512 524 533 536]
#     Exploring key '20_4':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (6489, 1) and dtype uint16
#         Content (first element): [491 490 489 489]
#     Exploring key '14':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (144774, 1) and dtype uint16
#         Content (first element): [491 491 492 492]
#     Exploring key '24':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (89964, 1) and dtype uint16
#         Content (first element): [500 501 501 501]
#     Exploring key '10_5':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (31311, 1) and dtype uint16
#         Content (first element): [502 510 519 530]
#     Exploring key '20_6':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (6489, 1) and dtype uint16
#         Content (first element): [491 491 491 491]
#     Exploring key '13':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (145719, 1) and dtype uint16
#         Content (first element): [496 496 495 495]
#     Exploring key '23':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (107289, 1) and dtype uint16
#         Content (first element): [496 498 498 498]
#     Exploring key '10_7':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (31941, 1) and dtype uint16
#         Content (first element): [489 489 490 490]
#     Exploring key '20_8':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (6993, 1) and dtype uint16
#         Content (first element): [490 491 491 490]
#     Exploring key '12':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (145026, 1) and dtype uint16
#         Content (first element): [489 489 489 489]
# Exploring key '2113_1':
#   List of 1 items
#   Exploring list item 0:
#     Dict with keys: ['10', '20', '14', '24', '10_1', '20_2', '16', '26', '10_3', '20_4', '15', '25', '10_5', '20_6', '11', '21', '10_7', '20_8', '13', '23', '10_9', '20_10', '12']
#     Exploring key '10':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (30996, 1) and dtype uint16
#         Content (first element): [514 518 517 508]
#     Exploring key '20':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (9513, 1) and dtype uint16
#         Content (first element): [480 481 487 493]
#     Exploring key '14':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (155736, 1) and dtype uint16
#         Content (first element): [480 480 480 480]
#     Exploring key '24':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (89523, 1) and dtype uint16
#         Content (first element): [470 469 469 469]
#     Exploring key '10_1':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (31689, 1) and dtype uint16
#         Content (first element): [503 502 500 499]
#     Exploring key '20_2':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (8064, 1) and dtype uint16
#         Content (first element): [483 487 493 498]
#     Exploring key '16':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (154224, 1) and dtype uint16
#         Content (first element): [497 498 499 500]
#     Exploring key '26':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (81963, 1) and dtype uint16
#         Content (first element): [462 461 459 457]
#     Exploring key '10_3':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (31059, 1) and dtype uint16
#         Content (first element): [515 515 514 514]
#     Exploring key '20_4':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (24192, 1) and dtype uint16
#         Content (first element): [505 506 507 507]
#     Exploring key '15':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (155799, 1) and dtype uint16
#         Content (first element): [455 455 454 453]
#     Exploring key '25':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (127701, 1) and dtype uint16
#         Content (first element): [525 526 527 526]
#     Exploring key '10_5':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (31500, 1) and dtype uint16
#         Content (first element): [466 467 467 467]
#     Exploring key '20_6':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (5544, 1) and dtype uint16
#         Content (first element): [469 469 469 469]
#     Exploring key '11':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (146475, 1) and dtype uint16
#         Content (first element): [484 485 485 485]
#     Exploring key '21':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (82782, 1) and dtype uint16
#         Content (first element): [524 526 527 529]
#     Exploring key '10_7':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (31500, 1) and dtype uint16
#         Content (first element): [547 536 526 521]
#     Exploring key '20_8':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (6993, 1) and dtype uint16
#         Content (first element): [516 515 515 514]
#     Exploring key '13':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (145215, 1) and dtype uint16
#         Content (first element): [467 467 468 468]
#     Exploring key '23':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (91539, 1) and dtype uint16
#         Content (first element): [461 464 468 472]
#     Exploring key '10_9':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (31248, 1) and dtype uint16
#         Content (first element): [504 505 505 507]
#     Exploring key '20_10':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (6489, 1) and dtype uint16
#         Content (first element): [512 512 512 512]
#     Exploring key '12':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (145467, 1) and dtype uint16
#         Content (first element): [523 522 520 519]
# Exploring key '2122_1':
#   List of 1 items
#   Exploring list item 0:
#     Dict with keys: ['10', '20', '15', '25', '10_1', '20_2', '16', '26', '10_3', '20_4', '14', '24', '10_5', '20_6', '12', '22', '10_7', '20_8', '13', '23', '10_9', '20_10', '11']
#     Exploring key '10':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (31248, 1) and dtype uint16
#         Content (first element): [504 504 504 503]
#     Exploring key '20':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (16002, 1) and dtype uint16
#         Content (first element): [508 508 508 509]
#     Exploring key '15':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (159264, 1) and dtype uint16
#         Content (first element): [501 506 514 522]
#     Exploring key '25':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (95760, 1) and dtype uint16
#         Content (first element): [519 523 525 525]
#     Exploring key '10_1':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (32256, 1) and dtype uint16
#         Content (first element): [499 499 500 500]
#     Exploring key '20_2':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (6489, 1) and dtype uint16
#         Content (first element): [500 500 500 500]
#     Exploring key '16':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (158949, 1) and dtype uint16
#         Content (first element): [497 497 498 497]
#     Exploring key '26':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (92547, 1) and dtype uint16
#         Content (first element): [382 383 384 386]
#     Exploring key '10_3':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (32004, 1) and dtype uint16
#         Content (first element): [504 503 503 502]
#     Exploring key '20_4':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (9009, 1) and dtype uint16
#         Content (first element): [530 529 528 527]
#     Exploring key '14':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (155232, 1) and dtype uint16
#         Content (first element): [507 506 508 512]
#     Exploring key '24':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (121716, 1) and dtype uint16
#         Content (first element): [447 448 448 449]
#     Exploring key '10_5':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (30744, 1) and dtype uint16
#         Content (first element): [428 433 439 445]
#     Exploring key '20_6':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (4536, 1) and dtype uint16
#         Content (first element): [460 460 459 458]
#     Exploring key '12':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (144522, 1) and dtype uint16
#         Content (first element): [500 499 499 499]
#     Exploring key '22':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (102690, 1) and dtype uint16
#         Content (first element): [501 501 501 501]
#     Exploring key '10_7':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (32256, 1) and dtype uint16
#         Content (first element): [499 498 496 494]
#     Exploring key '20_8':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (6048, 1) and dtype uint16
#         Content (first element): [496 486 477 473]
#     Exploring key '13':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (145971, 1) and dtype uint16
#         Content (first element): [436 435 435 436]
#     Exploring key '23':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (97272, 1) and dtype uint16
#         Content (first element): [471 470 470 470]
#     Exploring key '10_9':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (32004, 1) and dtype uint16
#         Content (first element): [502 501 501 501]
#     Exploring key '20_10':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (7749, 1) and dtype uint16
#         Content (first element): [508 509 509 509]
#     Exploring key '11':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (145467, 1) and dtype uint16
#         Content (first element): [501 500 499 498]
# Exploring key '2110_1':
#   List of 1 items
#   Exploring list item 0:
#     Dict with keys: ['10', '20', '16', '26', '10_1', '20_2', '15', '25', '10_3', '20_4', '14', '24', '10_5', '20_6', '13', '23', '10_7', '20_8', '12', '22', '10_9', '20_10', '11']
#     Exploring key '10':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (30744, 1) and dtype uint16
#         Content (first element): [491 491 491 491]
#     Exploring key '20':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (11529, 1) and dtype uint16
#         Content (first element): [493 492 492 492]
#     Exploring key '16':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (159957, 1) and dtype uint16
#         Content (first element): [489 489 490 489]
#     Exploring key '26':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (79506, 1) and dtype uint16
#         Content (first element): [503 503 502 500]
#     Exploring key '10_1':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (30492, 1) and dtype uint16
#         Content (first element): [488 487 487 487]
#     Exploring key '20_2':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (15750, 1) and dtype uint16
#         Content (first element): [497 496 495 497]
#     Exploring key '15':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (153531, 1) and dtype uint16
#         Content (first element): [500 499 499 498]
#     Exploring key '25':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (92988, 1) and dtype uint16
#         Content (first element): [488 488 488 488]
#     Exploring key '10_3':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (30240, 1) and dtype uint16
#         Content (first element): [491 491 491 492]
#     Exploring key '20_4':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (10017, 1) and dtype uint16
#         Content (first element): [487 488 490 492]
#     Exploring key '14':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (155988, 1) and dtype uint16
#         Content (first element): [493 493 493 494]
#     Exploring key '24':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (148491, 1) and dtype uint16
#         Content (first element): [493 492 492 492]
#     Exploring key '10_5':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (30492, 1) and dtype uint16
#         Content (first element): [493 494 494 494]
#     Exploring key '20_6':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (8505, 1) and dtype uint16
#         Content (first element): [497 498 499 500]
#     Exploring key '13':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (146286, 1) and dtype uint16
#         Content (first element): [494 494 494 494]
#     Exploring key '23':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (75978, 1) and dtype uint16
#         Content (first element): [489 488 488 488]
#     Exploring key '10_7':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (30744, 1) and dtype uint16
#         Content (first element): [493 493 492 492]
#     Exploring key '20_8':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (6489, 1) and dtype uint16
#         Content (first element): [487 487 489 495]
#     Exploring key '12':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (146538, 1) and dtype uint16
#         Content (first element): [489 492 493 493]
#     Exploring key '22':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (81207, 1) and dtype uint16
#         Content (first element): [491 491 491 492]
#     Exploring key '10_9':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (30744, 1) and dtype uint16
#         Content (first element): [504 505 505 505]
#     Exploring key '20_10':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (7308, 1) and dtype uint16
#         Content (first element): [497 496 496 497]
#     Exploring key '11':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (146223, 1) and dtype uint16
#         Content (first element): [484 485 485 486]
# Exploring key '2121_1':
#   List of 1 items
#   Exploring list item 0:
#     Dict with keys: ['10', '20', '12', '22', '10_1', '20_2', '11', '21', '10_3', '20_4', '13', '23', '10_5', '20_6', '15', '25', '10_7', '20_8', '14', '24', '10_9', '20_10', '16']
#     Exploring key '10':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (32004, 1) and dtype uint16
#         Content (first element): [499 499 499 499]
#     Exploring key '20':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (5985, 1) and dtype uint16
#         Content (first element): [502 502 502 502]
#     Exploring key '12':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (145971, 1) and dtype uint16
#         Content (first element): [499 499 499 499]
#     Exploring key '22':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (166005, 1) and dtype uint16
#         Content (first element): [482 481 481 481]
#     Exploring key '10_1':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (32760, 1) and dtype uint16
#         Content (first element): [508 509 508 508]
#     Exploring key '20_2':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (5733, 1) and dtype uint16
#         Content (first element): [494 493 492 491]
#     Exploring key '11':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (145782, 1) and dtype uint16
#         Content (first element): [488 488 488 488]
#     Exploring key '21':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (104202, 1) and dtype uint16
#         Content (first element): [503 503 502 502]
#     Exploring key '10_3':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (31248, 1) and dtype uint16
#         Content (first element): [498 499 499 499]
#     Exploring key '20_4':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (8253, 1) and dtype uint16
#         Content (first element): [486 478 473 474]
#     Exploring key '13':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (146034, 1) and dtype uint16
#         Content (first element): [483 483 483 484]
#     Exploring key '23':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (388521, 1) and dtype uint16
#         Content (first element): [480 481 484 488]
#     Exploring key '10_5':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (31437, 1) and dtype uint16
#         Content (first element): [491 491 491 491]
#     Exploring key '20_6':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (14553, 1) and dtype uint16
#         Content (first element): [493 493 493 493]
#     Exploring key '15':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (159201, 1) and dtype uint16
#         Content (first element): [496 496 495 495]
#     Exploring key '25':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (87003, 1) and dtype uint16
#         Content (first element): [499 499 498 498]
#     Exploring key '10_7':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (31248, 1) and dtype uint16
#         Content (first element): [487 489 491 491]
#     Exploring key '20_8':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (8757, 1) and dtype uint16
#         Content (first element): [500 491 480 470]
#     Exploring key '14':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (156996, 1) and dtype uint16
#         Content (first element): [494 494 494 493]
#     Exploring key '24':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (90279, 1) and dtype uint16
#         Content (first element): [491 491 493 495]
#     Exploring key '10_9':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (31500, 1) and dtype uint16
#         Content (first element): [505 505 505 504]
#     Exploring key '20_10':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (11718, 1) and dtype uint16
#         Content (first element): [499 499 499 498]
#     Exploring key '16':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (156744, 1) and dtype uint16
#         Content (first element): [504 504 502 497]
# Exploring key '2104_1':
#   List of 1 items
#   Exploring list item 0:
#     Dict with keys: ['10', '20', '11', '21', '10_1', '20_2', '12', '22', '10_3', '20_4', '13', '23', '10_5', '20_6', '14', '24', '10_7', '20_8', '15', '25', '10_9', '20_10', '16']
#     Exploring key '10':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (31500, 1) and dtype uint16
#         Content (first element): [518 518 520 521]
#     Exploring key '20':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (72765, 1) and dtype uint16
#         Content (first element): [513 512 511 510]
#     Exploring key '11':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (146979, 1) and dtype uint16
#         Content (first element): [504 505 504 503]
#     Exploring key '21':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (88011, 1) and dtype uint16
#         Content (first element): [502 502 501 502]
#     Exploring key '10_1':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (31248, 1) and dtype uint16
#         Content (first element): [503 503 505 507]
#     Exploring key '20_2':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (8505, 1) and dtype uint16
#         Content (first element): [498 499 500 501]
#     Exploring key '12':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (143514, 1) and dtype uint16
#         Content (first element): [504 504 504 504]
#     Exploring key '22':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (94500, 1) and dtype uint16
#         Content (first element): [499 500 501 501]
#     Exploring key '10_3':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (31248, 1) and dtype uint16
#         Content (first element): [492 492 491 489]
#     Exploring key '20_4':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (7749, 1) and dtype uint16
#         Content (first element): [479 483 487 490]
#     Exploring key '13':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (143010, 1) and dtype uint16
#         Content (first element): [509 510 510 510]
#     Exploring key '23':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (375228, 1) and dtype uint16
#         Content (first element): [514 511 508 505]
#     Exploring key '10_5':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (31248, 1) and dtype uint16
#         Content (first element): [490 491 491 490]
#     Exploring key '20_6':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (8001, 1) and dtype uint16
#         Content (first element): [490 490 489 487]
#     Exploring key '14':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (156996, 1) and dtype uint16
#         Content (first element): [522 522 522 521]
#     Exploring key '24':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (81270, 1) and dtype uint16
#         Content (first element): [414 415 415 416]
#     Exploring key '10_7':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (30996, 1) and dtype uint16
#         Content (first element): [499 499 499 499]
#     Exploring key '20_8':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (15246, 1) and dtype uint16
#         Content (first element): [490 490 490 490]
#     Exploring key '15':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (154476, 1) and dtype uint16
#         Content (first element): [491 491 491 491]
#     Exploring key '25':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (96768, 1) and dtype uint16
#         Content (first element): [467 467 467 467]
#     Exploring key '10_9':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (31752, 1) and dtype uint16
#         Content (first element): [548 549 549 549]
#     Exploring key '20_10':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (9009, 1) and dtype uint16
#         Content (first element): [508 511 512 512]
#     Exploring key '16':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (154980, 1) and dtype uint16
#         Content (first element): [514 514 514 516]
# Exploring key '2114_1':
#   List of 1 items
#   Exploring list item 0:
#     Dict with keys: ['10', '20', '13', '23', '10_1', '20_2', '11', '21', '10_3', '20_4', '12', '22', '10_5', '20_6', '16', '26', '10_7', '20_8', '14', '24', '10_9', '20_10', '15']
#     Exploring key '10':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (30996, 1) and dtype uint16
#         Content (first element): [520 513 506 502]
#     Exploring key '20':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (9261, 1) and dtype uint16
#         Content (first element): [494 494 494 494]
#     Exploring key '13':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (145215, 1) and dtype uint16
#         Content (first element): [504 504 504 504]
#     Exploring key '23':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (84546, 1) and dtype uint16
#         Content (first element): [483 483 483 483]
#     Exploring key '10_1':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (32256, 1) and dtype uint16
#         Content (first element): [489 489 489 489]
#     Exploring key '20_2':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (7497, 1) and dtype uint16
#         Content (first element): [507 507 507 507]
#     Exploring key '11':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (144459, 1) and dtype uint16
#         Content (first element): [497 497 497 497]
#     Exploring key '21':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (85491, 1) and dtype uint16
#         Content (first element): [481 481 481 481]
#     Exploring key '10_3':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (31248, 1) and dtype uint16
#         Content (first element): [509 502 498 496]
#     Exploring key '20_4':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (8253, 1) and dtype uint16
#         Content (first element): [491 491 491 491]
#     Exploring key '12':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (145530, 1) and dtype uint16
#         Content (first element): [509 509 508 508]
#     Exploring key '22':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (427266, 1) and dtype uint16
#         Content (first element): [459 460 460 461]
#     Exploring key '10_5':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (30996, 1) and dtype uint16
#         Content (first element): [495 495 496 496]
#     Exploring key '20_6':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (4977, 1) and dtype uint16
#         Content (first element): [484 492 501 510]
#     Exploring key '16':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (154476, 1) and dtype uint16
#         Content (first element): [491 491 491 490]
#     Exploring key '26':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (87003, 1) and dtype uint16
#         Content (first element): [493 493 493 492]
#     Exploring key '10_7':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (31248, 1) and dtype uint16
#         Content (first element): [497 496 496 496]
#     Exploring key '20_8':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (7497, 1) and dtype uint16
#         Content (first element): [490 490 491 491]
#     Exploring key '14':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (155799, 1) and dtype uint16
#         Content (first element): [486 486 486 486]
#     Exploring key '24':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (93996, 1) and dtype uint16
#         Content (first element): [503 503 503 503]
#     Exploring key '10_9':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (32760, 1) and dtype uint16
#         Content (first element): [493 493 493 494]
#     Exploring key '20_10':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (14490, 1) and dtype uint16
#         Content (first element): [502 502 503 504]
#     Exploring key '15':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (153720, 1) and dtype uint16
#         Content (first element): [484 484 484 484]
# Exploring key '2131_2':
#   List of 1 items
#   Exploring list item 0:
#     Dict with keys: ['10', '20', '16', '26', '10_1', '20_2', '15', '25', '10_3', '20_4', '14', '24', '10_5', '20_6', '13', '23', '10_7', '20_8', '12', '22', '10_9', '20_10', '11']
#     Exploring key '10':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (32256, 1) and dtype uint16
#         Content (first element): [494 494 494 494]
#     Exploring key '20':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (6993, 1) and dtype uint16
#         Content (first element): [538 547 549 543]
#     Exploring key '16':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (154728, 1) and dtype uint16
#         Content (first element): [480 480 480 481]
#     Exploring key '26':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (101808, 1) and dtype uint16
#         Content (first element): [497 497 497 497]
#     Exploring key '10_1':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (31752, 1) and dtype uint16
#         Content (first element): [487 487 487 487]
#     Exploring key '20_2':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (13230, 1) and dtype uint16
#         Content (first element): [486 487 487 488]
#     Exploring key '15':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (152712, 1) and dtype uint16
#         Content (first element): [492 492 491 491]
#     Exploring key '25':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (91035, 1) and dtype uint16
#         Content (first element): [496 495 495 495]
#     Exploring key '10_3':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (31248, 1) and dtype uint16
#         Content (first element): [504 505 506 507]
#     Exploring key '20_4':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (7497, 1) and dtype uint16
#         Content (first element): [491 491 492 492]
#     Exploring key '14':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (156996, 1) and dtype uint16
#         Content (first element): [493 493 493 493]
#     Exploring key '24':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (109746, 1) and dtype uint16
#         Content (first element): [492 491 490 492]
#     Exploring key '10_5':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (30996, 1) and dtype uint16
#         Content (first element): [492 492 492 492]
#     Exploring key '20_6':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (5733, 1) and dtype uint16
#         Content (first element): [487 487 489 489]
#     Exploring key '13':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (146538, 1) and dtype uint16
#         Content (first element): [487 487 488 489]
#     Exploring key '23':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (81711, 1) and dtype uint16
#         Content (first element): [486 487 488 488]
#     Exploring key '10_7':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (31248, 1) and dtype uint16
#         Content (first element): [490 490 490 489]
#     Exploring key '20_8':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (3780, 1) and dtype uint16
#         Content (first element): [502 502 501 500]
#     Exploring key '12':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (146223, 1) and dtype uint16
#         Content (first element): [487 487 487 487]
#     Exploring key '22':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (76797, 1) and dtype uint16
#         Content (first element): [475 475 475 476]
#     Exploring key '10_9':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (30996, 1) and dtype uint16
#         Content (first element): [484 484 484 484]
#     Exploring key '20_10':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (5481, 1) and dtype uint16
#         Content (first element): [497 497 497 497]
#     Exploring key '11':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (146223, 1) and dtype uint16
#         Content (first element): [489 489 489 489]
# Exploring key '2120_1':
#   List of 1 items
#   Exploring list item 0:
# ...
#     Exploring key '23':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (197946, 1) and dtype uint16
#         Content (first element): [488 488 489 490]
#     Exploring key '10_5':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (30051, 1) and dtype uint16
#         Content (first element): [490 490 491 491]
#     Exploring key '20_6':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (9261, 1) and dtype uint16
#         Content (first element): [488 489 489 489]
#     Exploring key '15':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (152460, 1) and dtype uint16
#         Content (first element): [610 613 597 565]
#     Exploring key '25':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (91035, 1) and dtype uint16
#         Content (first element): [589 608 608 588]
#     Exploring key '10_7':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (30996, 1) and dtype uint16
#         Content (first element): [486 486 486 486]
#     Exploring key '20_8':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (2457, 1) and dtype uint16
#         Content (first element): [489 489 489 489]
#     Exploring key '14':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (152775, 1) and dtype uint16
#         Content (first element): [488 488 488 488]
#     Exploring key '24':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (90468, 1) and dtype uint16
#         Content (first element): [490 490 490 490]
#     Exploring key '10_9':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (25011, 1) and dtype uint16
#         Content (first element): [492 492 491 491]
#     Exploring key '20_10':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (2268, 1) and dtype uint16
#         Content (first element): [487 487 487 487]
#     Exploring key '16':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (158004, 1) and dtype uint16
#         Content (first element): [490 490 490 491]
# Exploring key '2106_1':
#   List of 1 items
#   Exploring list item 0:
#     Dict with keys: ['10', '20', '13', '23', '10_1', '20_2', '11', '21', '10_3', '20_4', '12', '22', '10_5', '20_6', '16', '26', '10_7', '20_8', '14', '24', '10_9', '20_10', '15']
#     Exploring key '10':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (31752, 1) and dtype uint16
#         Content (first element): [491 491 491 491]
#     Exploring key '20':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (10521, 1) and dtype uint16
#         Content (first element): [497 498 498 499]
#     Exploring key '13':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (145467, 1) and dtype uint16
#         Content (first element): [494 494 494 495]
#     Exploring key '23':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (91980, 1) and dtype uint16
#         Content (first element): [490 491 491 491]
#     Exploring key '10_1':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (30807, 1) and dtype uint16
#         Content (first element): [488 488 488 488]
#     Exploring key '20_2':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (3969, 1) and dtype uint16
#         Content (first element): [498 497 497 497]
#     Exploring key '11':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (146979, 1) and dtype uint16
#         Content (first element): [503 504 504 504]
#     Exploring key '21':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (83034, 1) and dtype uint16
#         Content (first element): [508 506 505 504]
#     Exploring key '10_3':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (30996, 1) and dtype uint16
#         Content (first element): [481 479 477 475]
#     Exploring key '20_4':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (2520, 1) and dtype uint16
#         Content (first element): [498 499 499 500]
#     Exploring key '12':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (145467, 1) and dtype uint16
#         Content (first element): [445 445 445 445]
#     Exploring key '22':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (372015, 1) and dtype uint16
#         Content (first element): [503 504 506 508]
#     Exploring key '10_5':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (32508, 1) and dtype uint16
#         Content (first element): [631 635 645 654]
#     Exploring key '20_6':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (12978, 1) and dtype uint16
#         Content (first element): [491 490 490 490]
#     Exploring key '16':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (155736, 1) and dtype uint16
#         Content (first element): [378 379 379 380]
#     Exploring key '26':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (86499, 1) and dtype uint16
#         Content (first element): [510 511 512 512]
#     Exploring key '10_7':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (30744, 1) and dtype uint16
#         Content (first element): [585 587 590 592]
#     Exploring key '20_8':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (12033, 1) and dtype uint16
#         Content (first element): [78 77 74 74]
#     Exploring key '14':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (160461, 1) and dtype uint16
#         Content (first element): [514 514 512 511]
#     Exploring key '24':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (90531, 1) and dtype uint16
#         Content (first element): [540 532 515 497]
#     Exploring key '10_9':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (31500, 1) and dtype uint16
#         Content (first element): [34 38 58 74]
#     Exploring key '20_10':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (22995, 1) and dtype uint16
#         Content (first element): [506 504 503 507]
#     Exploring key '15':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (155484, 1) and dtype uint16
#         Content (first element): [489 489 490 490]
# Exploring key '2124_1':
#   List of 1 items
#   Exploring list item 0:
#     Dict with keys: ['10', '20', '16']
#     Exploring key '10':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (32256, 1) and dtype uint16
#         Content (first element): [487 487 488 488]
#     Exploring key '20':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (14994, 1) and dtype uint16
#         Content (first element): [507 506 506 505]
#     Exploring key '16':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (154224, 1) and dtype uint16
#         Content (first element): [496 496 496 496]
# Exploring key '2125_1':
#   List of 1 items
#   Exploring list item 0:
#     Dict with keys: ['10', '20', '14', '24', '10_1', '20_2', '16', '26', '10_3', '20_4', '15', '25', '10_5', '20_6', '11', '21', '10_7', '20_8', '13', '23', '10_9', '20_10', '12']
#     Exploring key '10':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (31248, 1) and dtype uint16
#         Content (first element): [504 516 533 552]
#     Exploring key '20':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (12222, 1) and dtype uint16
#         Content (first element): [494 495 497 498]
#     Exploring key '14':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (154539, 1) and dtype uint16
#         Content (first element): [493 493 494 494]
#     Exploring key '24':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (91476, 1) and dtype uint16
#         Content (first element): [497 498 499 500]
#     Exploring key '10_1':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (32508, 1) and dtype uint16
#         Content (first element): [489 489 489 489]
#     Exploring key '20_2':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (9009, 1) and dtype uint16
#         Content (first element): [494 494 493 492]
#     Exploring key '16':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (154476, 1) and dtype uint16
#         Content (first element): [487 487 486 486]
#     Exploring key '26':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (75537, 1) and dtype uint16
#         Content (first element): [486 486 486 486]
#     Exploring key '10_3':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (32445, 1) and dtype uint16
#         Content (first element): [484 484 484 484]
#     Exploring key '20_4':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (15750, 1) and dtype uint16
#         Content (first element): [499 499 499 499]
#     Exploring key '15':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (156303, 1) and dtype uint16
#         Content (first element): [490 490 490 490]
#     Exploring key '25':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (118188, 1) and dtype uint16
#         Content (first element): [491 487 490 494]
#     Exploring key '10_5':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (33012, 1) and dtype uint16
#         Content (first element): [491 491 492 492]
#     Exploring key '20_6':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (8253, 1) and dtype uint16
#         Content (first element): [495 495 495 495]
#     Exploring key '11':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (149499, 1) and dtype uint16
#         Content (first element): [491 491 491 491]
#     Exploring key '21':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (170982, 1) and dtype uint16
#         Content (first element): [458 459 459 459]
#     Exploring key '10_7':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (32508, 1) and dtype uint16
#         Content (first element): [534 509 492 487]
#     Exploring key '20_8':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (7497, 1) and dtype uint16
#         Content (first element): [486 486 486 486]
#     Exploring key '13':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (146790, 1) and dtype uint16
#         Content (first element): [554 530 508 494]
#     Exploring key '23':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (74718, 1) and dtype uint16
#         Content (first element): [523 523 521 519]
#     Exploring key '10_9':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (33264, 1) and dtype uint16
#         Content (first element): [487 486 486 486]
#     Exploring key '20_10':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (4977, 1) and dtype uint16
#         Content (first element): [536 552 560 555]
#     Exploring key '12':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (146286, 1) and dtype uint16
#         Content (first element): [488 488 488 488]
# Exploring key '2136_1':
#   List of 1 items
#   Exploring list item 0:
#     Dict with keys: ['10', '20', '11', '21', '10_1', '20_2', '12', '22', '10_3', '20_4', '13', '23', '10_5', '20_6', '14', '24', '10_7', '20_8', '15', '25', '10_9', '20_10', '16']
#     Exploring key '10':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (29988, 1) and dtype uint16
#         Content (first element): [494 494 494 494]
#     Exploring key '20':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (252, 1) and dtype uint16
#         Content (first element): [492 491 491 491]
#     Exploring key '11':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (143514, 1) and dtype uint16
#         Content (first element): [491 491 491 491]
#     Exploring key '21':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (89712, 1) and dtype uint16
#         Content (first element): [498 498 498 498]
#     Exploring key '10_1':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (30051, 1) and dtype uint16
#         Content (first element): [498 498 499 499]
#     Exploring key '20_2':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (1197, 1) and dtype uint16
#         Content (first element): [495 495 495 494]
#     Exploring key '12':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (145278, 1) and dtype uint16
#         Content (first element): [475 482 488 490]
#     Exploring key '22':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (88263, 1) and dtype uint16
#         Content (first element): [491 491 492 492]
#     Exploring key '10_3':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (29988, 1) and dtype uint16
#         Content (first element): [494 494 494 493]
#     Exploring key '20_4':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (1512, 1) and dtype uint16
#         Content (first element): [491 489 489 495]
#     Exploring key '13':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (145971, 1) and dtype uint16
#         Content (first element): [493 493 493 492]
#     Exploring key '23':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (280980, 1) and dtype uint16
#         Content (first element): [493 490 489 491]
#     Exploring key '10_5':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (30051, 1) and dtype uint16
#         Content (first element): [493 493 492 492]
#     Exploring key '20_6':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (1197, 1) and dtype uint16
#         Content (first element): [497 496 496 497]
#     Exploring key '14':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (163800, 1) and dtype uint16
#         Content (first element): [492 492 492 493]
#     Exploring key '24':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (95760, 1) and dtype uint16
#         Content (first element): [485 486 486 486]
#     Exploring key '10_7':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (29988, 1) and dtype uint16
#         Content (first element): [498 498 499 499]
#     Exploring key '20_8':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (8694, 1) and dtype uint16
#         Content (first element): [490 490 491 491]
#     Exploring key '15':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (155295, 1) and dtype uint16
#         Content (first element): [502 503 502 503]
#     Exploring key '25':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (82971, 1) and dtype uint16
#         Content (first element): [496 497 497 497]
#     Exploring key '10_9':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (29988, 1) and dtype uint16
#         Content (first element): [487 485 483 485]
#     Exploring key '20_10':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (2268, 1) and dtype uint16
#         Content (first element): [506 507 507 508]
#     Exploring key '16':
#       List of 1 items
#       Exploring list item 0:
#         Array with shape (152523, 1) and dtype uint16
#         Content (first element): [491 491 491 491]

# %%
ecg_signals['2107_1'][0]['10'][0]
# Out:
# array([[492],
#        [492],
#        [492],
#        ...,
#        [494],
#        [494],
#        [493]], dtype=uint16)
